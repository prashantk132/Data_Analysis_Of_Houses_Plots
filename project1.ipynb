# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('train.csv')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df['MSZoning'].value_counts()
# Out:
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: count, dtype: int64

# %%
sns.countplot(x='MSZoning',data=df)
# Out:
# <Axes: xlabel='MSZoning', ylabel='count'>

# %% [markdown]
# Residential Low type of density is much higher than others then followed by Residential Medium Density.

# %%
df['Street'].value_counts()
# Out:
# Street
# Pave    1454
# Grvl       6
# Name: count, dtype: int64

# %%
sns.countplot(x='Street',data=df)
# Out:
# <Axes: xlabel='Street', ylabel='count'>

# %% [markdown]
# We can see count of pave type of street is much higher than Grvl.

# %%
df['Alley'].value_counts()
# Out:
# Alley
# Grvl    50
# Pave    41
# Name: count, dtype: int64

# %%
sns.countplot(x='Alley',data=df)
# Out:
# <Axes: xlabel='Alley', ylabel='count'>

# %% [markdown]
# Grvl type of alley is more than paved.

# %%
df['LotShape'].value_counts()
# Out:
# LotShape
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: count, dtype: int64

# %%
sns.countplot(x='LotShape',data=df)
# Out:
# <Axes: xlabel='LotShape', ylabel='count'>

# %% [markdown]
# Regular type of LotShape is highest and then followed by Slightly irregular. Moderately irregular and irregular are the least.

# %%
df['LandContour'].value_counts()
# Out:
# LandContour
# Lvl    1311
# Bnk      63
# HLS      50
# Low      36
# Name: count, dtype: int64

# %%
sns.countplot(x='LandContour',data=df)
# Out:
# <Axes: xlabel='LandContour', ylabel='count'>

# %% [markdown]
# The flatness of the area is good or near Flat/Level. But some of them are banked, depression and hillside.

# %%
df['Utilities'].value_counts()
# Out:
# Utilities
# AllPub    1459
# NoSeWa       1
# Name: count, dtype: int64

# %%
sns.countplot(x='Utilities',data=df)
# Out:
# <Axes: xlabel='Utilities', ylabel='count'>

# %% [markdown]
# Public Facilities are available almost everywhere except some few area.

# %%
df['LandSlope'].value_counts()
# Out:
# LandSlope
# Gtl    1382
# Mod      65
# Sev      13
# Name: count, dtype: int64

# %%
sns.countplot(x='LandSlope',data=df)
# Out:
# <Axes: xlabel='LandSlope', ylabel='count'>

# %% [markdown]
# The area has mostly Gentle Slope, some of them are Moderate Slope and very few of them are Severe Slope.

# %%
df['HouseStyle'].value_counts()
# Out:
# HouseStyle
# 1Story    726
# 2Story    445
# 1.5Fin    154
# SLvl       65
# SFoyer     37
# 1.5Unf     14
# 2.5Unf     11
# 2.5Fin      8
# Name: count, dtype: int64

# %%
sns.countplot(x='HouseStyle',data=df)
# Out:
# <Axes: xlabel='HouseStyle', ylabel='count'>

# %% [markdown]
# 1Story and 2Story are in majority.

# %%
df['RoofStyle'].value_counts()
# Out:
# RoofStyle
# Gable      1141
# Hip         286
# Flat         13
# Gambrel      11
# Mansard       7
# Shed          2
# Name: count, dtype: int64

# %%
sns.countplot(x='RoofStyle',data=df)
# Out:
# <Axes: xlabel='RoofStyle', ylabel='count'>

# %% [markdown]
# Majority of the plots are having Gable type roof and then followed by Hip type.

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df['RoofMatl'].value_counts()
# Out:
# RoofMatl
# CompShg    1434
# Tar&Grv      11
# WdShngl       6
# WdShake       5
# Metal         1
# Membran       1
# Roll          1
# ClyTile       1
# Name: count, dtype: int64

# %%
sns.countplot(x='RoofMatl',data=df)
# Out:
# <Axes: xlabel='RoofMatl', ylabel='count'>

# %% [markdown]
# Materials of the majority of the roofs are Standard Shingle.

# %%
df['Foundation'].value_counts()
# Out:
# Foundation
# PConc     647
# CBlock    634
# BrkTil    146
# Slab       24
# Stone       6
# Wood        3
# Name: count, dtype: int64

# %%
sns.countplot(x='Foundation',data=df)
# Out:
# <Axes: xlabel='Foundation', ylabel='count'>

# %% [markdown]
# Foundation of majority of plots are Poured Concrete and Cinder Block and followed by Brick & Tile.

# %%
df['ExterQual'].value_counts()
# Out:
# ExterQual
# TA    906
# Gd    488
# Ex     52
# Fa     14
# Name: count, dtype: int64

# %%
sns.countplot(x='ExterQual',data=df)
# Out:
# <Axes: xlabel='ExterQual', ylabel='count'>

# %% [markdown]
# Quality of most of the material on the exterior are Average/Typical or Good.

# %%
df['ExterCond'].value_counts()
# Out:
# ExterCond
# TA    1282
# Gd     146
# Fa      28
# Ex       3
# Po       1
# Name: count, dtype: int64

# %%
sns.countplot(x='ExterCond',data=df)
# Out:
# <Axes: xlabel='ExterCond', ylabel='count'>

# %% [markdown]
# Present condition of most of the material on the exterior are Typical/Average or Good.

# %%
df['Heating'].value_counts()
# Out:
# Heating
# GasA     1428
# GasW       18
# Grav        7
# Wall        4
# OthW        2
# Floor       1
# Name: count, dtype: int64

# %%
sns.countplot(x='Heating',data=df)
# Out:
# <Axes: xlabel='Heating', ylabel='count'>

# %% [markdown]
# Gas forced warm air furnace is used in majority.

# %%
df['HeatingQC'].value_counts()
# Out:
# HeatingQC
# Ex    741
# TA    428
# Gd    241
# Fa     49
# Po      1
# Name: count, dtype: int64

# %%
sns.countplot(x='HeatingQC',data=df)
# Out:
# <Axes: xlabel='HeatingQC', ylabel='count'>

# %% [markdown]
# Excellent Heating > 700 , Good Heating > 200 , Average/Typical > 400 , Fair Heating = 49 , Poor Heating = 1.

# %%
df['CentralAir'].value_counts()
# Out:
# CentralAir
# Y    1365
# N      95
# Name: count, dtype: int64

# %%
sns.countplot(x='CentralAir',data=df)
# Out:
# <Axes: xlabel='CentralAir', ylabel='count'>

# %% [markdown]
# The majority are YES.

# %%
df['Electrical'].value_counts()
# Out:
# Electrical
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: count, dtype: int64

# %%
sns.countplot(x='Electrical',data=df)
# Out:
# <Axes: xlabel='Electrical', ylabel='count'>

# %% [markdown]
# Standard Circuit Breaker & Romex are the highest then followed by FuseA Electrical.

# %%
df['KitchenQual'].value_counts()
# Out:
# KitchenQual
# TA    735
# Gd    586
# Ex    100
# Fa     39
# Name: count, dtype: int64

# %%
sns.countplot(x='KitchenQual',data=df)
# Out:
# <Axes: xlabel='KitchenQual', ylabel='count'>

# %% [markdown]
# Good > 500 , Average/Typical > 700 , Excellent = 100 , Fair < 100.

# %%
df['Functional'].value_counts()
# Out:
# Functional
# Typ     1360
# Min2      34
# Min1      31
# Mod       15
# Maj1      14
# Maj2       5
# Sev        1
# Name: count, dtype: int64

# %%
sns.countplot(x='Functional',data=df)
# Out:
# <Axes: xlabel='Functional', ylabel='count'>

# %% [markdown]
# Majority are Typical Functionality.

# %%
df['FireplaceQu'].value_counts()
# Out:
# FireplaceQu
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: count, dtype: int64

# %%
sns.countplot(x='FireplaceQu',data=df)
# Out:
# <Axes: xlabel='FireplaceQu', ylabel='count'>

# %% [markdown]
# Fireplace Quality : Average/Typical > 300 , Good > 350 , Fair < 50 , Excellent < Fair , Poor < Excellent.

# %%
df['GarageType'].value_counts()
# Out:
# GarageType
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: count, dtype: int64

# %%
sns.countplot(x='GarageType',data=df)
# Out:
# <Axes: xlabel='GarageType', ylabel='count'>

# %% [markdown]
# Majority of the GarageType are Attached to home then followed by Detached from home and Built-In.

# %%
df['GarageQual'].value_counts()
# Out:
# GarageQual
# TA    1311
# Fa      48
# Gd      14
# Ex       3
# Po       3
# Name: count, dtype: int64

# %%
sns.countplot(x='GarageQual',data=df)
# Out:
# <Axes: xlabel='GarageQual', ylabel='count'>

# %% [markdown]
# Majority of Garage Quality are Average/Typical.

# %%
df['GarageCond'].value_counts()
# Out:
# GarageCond
# TA    1326
# Fa      35
# Gd       9
# Po       7
# Ex       2
# Name: count, dtype: int64

# %%
sns.countplot(x='GarageCond',data=df)
# Out:
# <Axes: xlabel='GarageCond', ylabel='count'>

# %% [markdown]
# Majority of Garage Condition are Average/Typical.

# %%
df['PoolQC'].value_counts()
# Out:
# PoolQC
# Gd    3
# Ex    2
# Fa    2
# Name: count, dtype: int64

# %%
sns.countplot(x='PoolQC',data=df)
# Out:
# <Axes: xlabel='PoolQC', ylabel='count'>

# %% [markdown]
# Pool Quality : Excellent = 2 , Fair = 2 , Good = 3.

# %%
df['Fence'].value_counts()
# Out:
# Fence
# MnPrv    157
# GdPrv     59
# GdWo      54
# MnWw      11
# Name: count, dtype: int64

# %%
sns.countplot(x='Fence',data=df)
# Out:
# <Axes: xlabel='Fence', ylabel='count'>

# %% [markdown]
# Fence : Minimum Privacy > 140 , Good Wood (GdWo0 > 40 , Good Privacy (GdPrv) ~ 60 , Minimum wood/wire < 20 .

# %%
df['SaleType'].value_counts()
# Out:
# SaleType
# WD       1267
# New       122
# COD        43
# ConLD       9
# ConLI       5
# ConLw       5
# CWD         4
# Oth         3
# Con         2
# Name: count, dtype: int64

# %%
sns.countplot(x='SaleType',data=df)
# Out:
# <Axes: xlabel='SaleType', ylabel='count'>

# %% [markdown]
# Type of Sale : WD >> New > COD > OTHERS.

# %%
df['SaleCondition'].value_counts()
# Out:
# SaleCondition
# Normal     1198
# Partial     125
# Abnorml     101
# Family       20
# Alloca       12
# AdjLand       4
# Name: count, dtype: int64

# %%
sns.countplot(x='SaleCondition',data=df)
# Out:
# <Axes: xlabel='SaleCondition', ylabel='count'>

# %% [markdown]
# Sale Condition : Normal ~ 1200 , AdjLand < Alloca < Family < Abnormal < Partial < 200 .

# %%
sns.barplot(x='OverallQual', y='YearBuilt', data=df)
# Out:
# <Axes: xlabel='OverallQual', ylabel='YearBuilt'>

# %% [markdown]
# On an average Modernisation leads to improve in Quality.

# %%
sns.barplot(x='SaleCondition',y='SalePrice',data=df)
# Out:
# <Axes: xlabel='SaleCondition', ylabel='SalePrice'>

# %% [markdown]
# Average Price of Sale Contion : Partial > Normal > Alloca > Family > Abnormal > AdjLand

# %%
sns.barplot(x='ExterQual',y='SalePrice',data=df)
# Out:
# <Axes: xlabel='ExterQual', ylabel='SalePrice'>

# %% [markdown]
# Comparison of Sale Price with External Quality : Excellent > Good > Typical/Average > Fair.

# %%
sns.barplot(x='ExterCond',y='SalePrice',data=df)
# Out:
# <Axes: xlabel='ExterCond', ylabel='SalePrice'>

# %% [markdown]
# Comparison of Sale Price with External Condition : Excellent > Typical/Average > Good > Fair > Poor.

# %%
sns.barplot(x='OverallQual',y='SalePrice',data=df)
# Out:
# <Axes: xlabel='OverallQual', ylabel='SalePrice'>

# %% [markdown]
# As Quality increase Sale Price also increases.

# %%
sns.barplot(x='OverallCond',y='SalePrice',data=df)
# Out:
# <Axes: xlabel='OverallCond', ylabel='SalePrice'>

# %% [markdown]
# Comparison of Sale Price with Overall Condition : 9 > 5 > 7 ~ 8 ~ 6 > 2 > 4 > 3 > 1.

# %%
sns.barplot(x='HouseStyle',y='SalePrice',data=df)
# Out:
# <Axes: xlabel='HouseStyle', ylabel='SalePrice'>

# %% [markdown]
# HousStyle vs SalePrice : 2.5 Fin > 2 Story > 1 Story > S Lvl > 2.5 Unf > 1.5 Fin > SFoyer > 1.5 Unf.

# %%
sns.barplot(x='LotShape',y='SalePrice',data=df)
# Out:
# <Axes: xlabel='LotShape', ylabel='SalePrice'>

# %% [markdown]
# LotShape vs SalePrice : Moderately Irregular > Irregular > Slightly Irregular > Regular.
